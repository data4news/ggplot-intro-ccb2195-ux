# %% [markdown]
# # Python and R
#
# This setup allows you to use *Python* and *R* in the same notebook.
#
# To set up a similar notebook, see quickstart instructions here:
#
# https://github.com/dmil/jupyter-quickstart

# %%
# Set R_HOME environment variable so rpy2 can find R
import os
os.environ['R_HOME'] = r'C:\Program Files\R\R-4.5.2'

# %pip install rpy2
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Error importing in API mode: ImportError('On Windows, cffi mode "ANY" is only "ABI".')
# Trying to import in ABI mode.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rpy2 in c:\users\craig\appdata\roaming\python\python314\site-packages (3.6.4)
# Requirement already satisfied: rpy2-rinterface>=3.6.3 in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2) (3.6.3)
# Requirement already satisfied: rpy2-robjects>=3.6.3 in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2) (3.6.3)
# Requirement already satisfied: packaging in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2) (25.0)
# Requirement already satisfied: cffi>=1.15.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2-rinterface>=3.6.3->rpy2) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\craig\appdata\roaming\python\python314\site-packages (from cffi>=1.15.1->rpy2-rinterface>=3.6.3->rpy2) (3.0)
# Requirement already satisfied: jinja2 in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2-robjects>=3.6.3->rpy2) (3.1.6)
# Requirement already satisfied: tzlocal in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2-robjects>=3.6.3->rpy2) (5.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jinja2->rpy2-robjects>=3.6.3->rpy2) (3.0.3)
# Requirement already satisfied: tzdata in c:\users\craig\appdata\roaming\python\python314\site-packages (from tzlocal->rpy2-robjects>=3.6.3->rpy2) (2025.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install R packages (tidyverse, etc.)
# Run this once to install required R packages
# !Rscript setup.R

# Install Python packages from requirements.txt
# %pip install -r requirements.txt
# Out:
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\craig\AppData\Local\Temp\RtmpYBFEAt\downloaded_packages
# package 'extrafontdb' successfully unpacked and MD5 sums checked
# package 'Rttf2pt1' successfully unpacked and MD5 sums checked
# package 'extrafont' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\craig\AppData\Local\Temp\RtmpYBFEAt\downloaded_packages
# package 'Cairo' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\craig\AppData\Local\Temp\RtmpYBFEAt\downloaded_packages
# package 'Rcpp' successfully unpacked and MD5 sums checked
# package 'credentials' successfully unpacked and MD5 sums checked
# package 'zip' successfully unpacked and MD5 sums checked
# package 'gitcreds' successfully unpacked and MD5 sums checked
# package 'ini' successfully unpacked and MD5 sums checked
# package 'httpuv' successfully unpacked and MD5 sums checked
# package 'later' successfully unpacked and MD5 sums checked
# package 'otel' successfully unpacked and MD5 sums checked
# package 'promises' successfully unpacked and MD5 sums checked
# package 'sourcetools' successfully unpacked and MD5 sums checked
# package 'xtable' successfully unpacked and MD5 sums checked
# package 'fansi' successfully unpacked and MD5 sums checked
# package 'diffobj' successfully unpacked and MD5 sums checked
# package 'gert' successfully unpacked and MD5 sums checked
# package 'gh' successfully unpacked and MD5 sums checked
# package 'whisker' successfully unpacked and MD5 sums checked
# package 'shiny' successfully unpacked and MD5 sums checked
# package 'downlit' successfully unpacked and MD5 sums checked
# package 'httr2' successfully unpacked and MD5 sums checked
# package 'htmlwidgets' successfully unpacked and MD5 sums checked
# package 'xopen' successfully unpacked and MD5 sums checked
# package 'brio' successfully unpacked and MD5 sums checked
# package 'praise' successfully unpacked and MD5 sums checked
# package 'waldo' successfully unpacked and MD5 sums checked
# package 'usethis' successfully unpacked and MD5 sums checked
# package 'ellipsis' successfully unpacked and MD5 sums checked
# package 'miniUI' successfully unpacked and MD5 sums checked
# package 'pkgdown' successfully unpacked and MD5 sums checked
# package 'profvis' successfully unpacked and MD5 sums checked
# package 'rcmdcheck' successfully unpacked and MD5 sums checked
# package 'remotes' successfully unpacked and MD5 sums checked
# package 'rversions' successfully unpacked and MD5 sums checked
# package 'sessioninfo' successfully unpacked and MD5 sums checked
# package 'testthat' successfully unpacked and MD5 sums checked
# package 'urlchecker' successfully unpacked and MD5 sums checked
# package 'devtools' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\craig\AppData\Local\Temp\RtmpYBFEAt\downloaded_packages
# package 'gridExtra' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\craig\AppData\Local\Temp\RtmpYBFEAt\downloaded_packages
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [1] "Successfully loaded: tidyverse" "Successfully loaded: extrafont"
# [3] "Successfully loaded: Cairo"     "Successfully loaded: devtools"
# [5] "Successfully loaded: gridExtra"
# Installing package into 'C:/Users/craig/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/tidyverse_2.0.0.zip'
# Content type 'application/zip' length 431680 bytes (421 KB)
# ==================================================
# downloaded 421 KB
#
# Installing package into 'C:/Users/craig/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# also installing the dependencies 'extrafontdb', 'Rttf2pt1'
#
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/extrafontdb_1.1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/Rttf2pt1_1.3.14.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/extrafont_0.20.zip'
# Installing package into 'C:/Users/craig/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/Cairo_1.7-0.zip'
# Content type 'application/zip' length 4634093 bytes (4.4 MB)
# ==================================================
# downloaded 4.4 MB
#
# Installing package into 'C:/Users/craig/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# also installing the dependencies 'Rcpp', 'credentials', 'zip', 'gitcreds', 'ini', 'httpuv', 'later', 'otel', 'promises', 'sourcetools', 'xtable', 'fansi', 'diffobj', 'gert', 'gh', 'whisker', 'shiny', 'downlit', 'httr2', 'htmlwidgets', 'xopen', 'brio', 'praise', 'waldo', 'usethis', 'ellipsis', 'miniUI', 'pkgdown', 'profvis', 'rcmdcheck', 'remotes', 'rversions', 'sessioninfo', 'testthat', 'urlchecker'
#
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/Rcpp_1.1.1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/credentials_2.0.3.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/zip_2.3.3.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/gitcreds_0.1.2.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/ini_0.3.1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/httpuv_1.6.16.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/later_1.4.5.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/otel_0.2.0.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/promises_1.5.0.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/sourcetools_0.1.7-1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/xtable_1.8-4.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/fansi_1.0.7.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/diffobj_0.3.6.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/gert_2.3.1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/gh_1.5.0.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/whisker_0.4.1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/shiny_1.12.1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/downlit_0.4.5.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/httr2_1.2.2.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/htmlwidgets_1.6.4.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/xopen_1.0.1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/brio_1.1.5.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/praise_1.0.0.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/waldo_0.6.2.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/usethis_3.2.1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/ellipsis_0.3.2.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/miniUI_0.1.2.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/pkgdown_2.2.0.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/profvis_0.4.0.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/rcmdcheck_1.4.0.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/remotes_2.5.0.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/rversions_3.0.0.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/sessioninfo_1.2.3.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/testthat_3.3.2.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/urlchecker_1.0.1.zip'
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/devtools_2.4.6.zip'
# Installing package into 'C:/Users/craig/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# trying URL 'http://cran.us.r-project.org/bin/windows/contrib/4.5/gridExtra_2.3.zip'
# Content type 'application/zip' length 1109646 bytes (1.1 MB)
# ==================================================
# downloaded 1.1 MB
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter in c:\users\craig\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: pandas in c:\users\craig\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\craig\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: rpy2 in c:\users\craig\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 4)) (3.6.4)
# Requirement already satisfied: tzlocal in c:\users\craig\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 5)) (5.3.1)
# Requirement already satisfied: matplotlib in c:\users\craig\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 6)) (3.10.8)
# Requirement already satisfied: notebook in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter->-r requirements.txt (line 1)) (7.5.3)
# Requirement already satisfied: jupyter-console in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter->-r requirements.txt (line 1)) (7.17.0)
# Requirement already satisfied: ipykernel in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter->-r requirements.txt (line 1)) (6.28.0)
# Requirement already satisfied: ipywidgets in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter->-r requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: jupyterlab in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter->-r requirements.txt (line 1)) (4.5.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from pandas->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\craig\appdata\roaming\python\python314\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\craig\appdata\roaming\python\python314\site-packages (from pandas->-r requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: rpy2-rinterface>=3.6.3 in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2->-r requirements.txt (line 4)) (3.6.3)
# Requirement already satisfied: rpy2-robjects>=3.6.3 in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2->-r requirements.txt (line 4)) (3.6.3)
# Requirement already satisfied: packaging in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\craig\appdata\roaming\python\python314\site-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from matplotlib->-r requirements.txt (line 6)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\craig\appdata\roaming\python\python314\site-packages (from matplotlib->-r requirements.txt (line 6)) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\craig\appdata\roaming\python\python314\site-packages (from matplotlib->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\craig\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: cffi>=1.15.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2-rinterface>=3.6.3->rpy2->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\craig\appdata\roaming\python\python314\site-packages (from cffi>=1.15.1->rpy2-rinterface>=3.6.3->rpy2->-r requirements.txt (line 4)) (3.0)
# Requirement already satisfied: jinja2 in c:\users\craig\appdata\roaming\python\python314\site-packages (from rpy2-robjects>=3.6.3->rpy2->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (9.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (7.2.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\craig\appdata\roaming\python\python314\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 1)) (4.5.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\craig\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\craig\appdata\roaming\python\python314\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jinja2->rpy2-robjects>=3.6.3->rpy2->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (80.10.2)
# Requirement already satisfied: anyio in c:\users\craig\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.12.1)
# Requirement already satisfied: certifi in c:\users\craig\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\craig\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in c:\users\craig\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\craig\appdata\roaming\python\python314\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: requests>=2.31 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\craig\appdata\roaming\python\python314\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\craig\appdata\roaming\python\python314\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\craig\appdata\roaming\python\python314\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\craig\appdata\roaming\python\python314\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\craig\appdata\roaming\python\python314\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\craig\appdata\roaming\python\python314\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\craig\appdata\roaming\python\python314\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\craig\appdata\roaming\python\python314\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.6.2)
# Requirement already satisfied: lark>=1.2.2 in c:\users\craig\appdata\roaming\python\python314\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\craig\appdata\roaming\python\python314\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\craig\appdata\roaming\python\python314\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# EXAMPLE PYTHON CELL
import pandas as pd
df = pd.read_csv('housing_data.csv')
df
# Out:
#        zip  population    borough  pct_hispanic_or_latino  pct_asian  \
# 0    11368      112088     QUEENS                   76.49      11.60
# 1    11385      107796     QUEENS                   45.05       6.46
# 2    11211      103123   BROOKLYN                   24.13       5.53
# 3    11208      101313   BROOKLYN                   40.58       6.01
# 4    10467      101255      BRONX                   52.08       5.68
# ..     ...         ...        ...                     ...        ...
# 184  10464        4531      BRONX                   42.02       5.01
# 185  10004        3335  MANHATTAN                    3.24      29.06
# 186  10006        3092  MANHATTAN                   10.83      16.04
# 187  10162        1486  MANHATTAN                   12.38       4.85
# 188  11430         206     QUEENS                   33.01       2.91
#
#      pct_american_indian_and_alaska_native  pct_black_or_african_american  \
# 0                                     0.09                           7.12
# 1                                     0.03                           1.77
# 2                                     0.19                           3.56
# 3                                     0.03                          48.89
# 4                                     0.35                          30.43
# ..                                     ...                            ...
# 184                                   0.00                           0.02
# 185                                   0.00                           3.96
# 186                                   0.00                           3.20
# 187                                   0.00                           0.00
# 188                                   0.00                          59.22
#
#      pct_white  pct_native_hawaiian_and_other_pacific_islander  \
# 0         3.73                                            0.00
# 1        45.28                                            0.00
# 2        64.24                                            0.02
# 3         2.71                                            0.00
# 4         9.24                                            0.02
# ..         ...                                             ...
# 184      52.50                                            0.00
# 185      59.28                                            0.51
# 186      64.52                                            0.00
# 187      79.48                                            0.00
# 188       4.85                                            0.00
#
#      pct_some_other_race  pct_two_or_more_races  pct_below_poverty
# 0                   0.37                   0.60              19.69
# 1                   0.32                   1.09              10.68
# 2                   0.29                   2.05              25.22
# 3                   0.76                   1.02              25.68
# 4                   0.76                   1.44              25.20
# ..                   ...                    ...                ...
# 184                 0.44                   0.00               7.11
# 185                 1.05                   2.91               1.32
# 186                 1.68                   3.72               3.36
# 187                 0.00                   3.30               0.00
# 188                 0.00                   0.00              72.77
#
# [189 rows x 12 columns]

# %% [markdown]
# ### Import packages

# %%
# %%R
#
# require('tidyverse')
# Out:
# -- Attaching core tidyverse packages ------------------------ tidyverse 2.0.0 --
# v dplyr     1.1.4     v readr     2.1.6
# v forcats   1.0.1     v stringr   1.6.0
# v ggplot2   4.0.1     v tibble    3.3.1
# v lubridate 1.9.4     v tidyr     1.3.2
# v purrr     1.2.1
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse

# %% [markdown]
# **Another way to import a package**
#
# Note that sometimes you might see
#
# ```R
# library('tidyverse')
# ```
#
# that also imports a library just the same as `require`
#
# **A note about tidyverse**
#
# The [Tidyverse](https://www.tidyverse.org/packages/) package is actually a bunch of other packages put together. So sometimes, you might see something like
#
# ```R
# require('ggplot2')
# require('readr')
# require('dplyr')
# require('tidyr')
# ```
#
# This also achieves the same purpose, but sometimes we just import the pakcages we need instead of the whole tidyverse.

# %% [markdown]
# ### Read Data
#
#
# This uses a function in the readr package to read a CSV file. Check out all the other cool things readr can do (like read from an excel file or a google doc)
#
# https://readr.tidyverse.org/

# %%
# %%R
#
# # Read data
# df <- read_csv('housing_data.csv')
# df
# Out:
# Rows: 189 Columns: 12
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr  (1): borough
# dbl (11): zip, population, pct_hispanic_or_latino, pct_asian, pct_american_i...
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 189 x 12
#      zip population borough  pct_hispanic_or_latino pct_asian
#    <dbl>      <dbl> <chr>                     <dbl>     <dbl>
#  1 11368     112088 QUEENS                    76.5      11.6
#  2 11385     107796 QUEENS                    45.0       6.46
#  3 11211     103123 BROOKLYN                  24.1       5.53
#  4 11208     101313 BROOKLYN                  40.6       6.01
#  5 10467     101255 BRONX                     52.1       5.68
#  6 11236     100844 BROOKLYN                   7.66      2.58
#  7 11226      99558 BROOKLYN                  16.4       3.07
#  8 11373      94437 QUEENS                    41.7      48.5
#  9 11234      93534 BROOKLYN                  11.1       7.19
# 10 11220      93170 BROOKLYN                  41.3      41.4
# # i 179 more rows
# # i 7 more variables: pct_american_indian_and_alaska_native <dbl>,
# #   pct_black_or_african_american <dbl>, pct_white <dbl>,
# #   pct_native_hawaiian_and_other_pacific_islander <dbl>,
# #   pct_some_other_race <dbl>, pct_two_or_more_races <dbl>,
# #   pct_below_poverty <dbl>
# # i Use `print(n = ...)` to see more rows

# %% [markdown]
# Notice that the assignment operator is `<-` rather than `=`. Actually, both work. Check out this really angry person's guide to R syntax. There are a LOT of punctuation marks in R.
#
# ![Screenshot%202023-01-20%20at%2011.47.03%20AM.png](images/r-assignment-operator.png)
#
# source: http://arrgh.tim-smith.us/syntax.html

# %% [markdown]
# # ggplot2
# ![image.png](attachment:image.png)
#
#
# Wahoo! Those are the basics. Now let's plot some **univariate** distributions in ggplot.

# %% [markdown]
# ### Histogram

# %%
# %%R
#
# # Plot
# ggplot(df)

# %%
# %%R
#
# # Plot +
# # Aesthetics
# ggplot(df) +
#     aes(x=pct_below_poverty)

# %%
# %%R
#
# # Plot +
# # Aesthetics +
# # Geom
# ggplot(df) +
#     aes(x=pct_below_poverty) +
#     geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.

# %%
# %%R
#
# # Plot +
# # Aesthetics +
# # Geom +
# # Theme
# ggplot(df) +
#     aes(x=pct_below_poverty) +
#     geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.

# %% [markdown]
# **👉 Try It**
#
# Here is an example of a histogram (above), and the documentation for geom_histogram (link below). Read the documentation and adjust the bin sizes (there are two ways to do this)
#
# https://ggplot2.tidyverse.org/reference/geom_histogram.html

# %%
# %%R
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Try It" question
#
# ggplot(df) +
#     aes(x=pct_below_poverty) +
#     geom_histogram(bins=40)

# %% [markdown]
# ### Dotplot

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_point()

# %% [markdown]
# **👉 Try It**
#
# Here is an example of a dotplot. It's super hard to read, check out some ggplot documentation and see if you can figure out how to make the dots bigger. Also, let's make them less opaque (more transparant) so that we can see where they overlap.

# %%
# %%R -w 1000 -h 200
#
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Try It" question
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1, color='red') +
#     geom_point(size=5, alpha=0.1)

# %% [markdown]
# **👉 Bonus**:  what does `geom_rug()` do?
# 1. try applying it to the above chart
# 2. and then google the offical ggplot documentation for it

# %%
# %%R
#
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Bonus" question
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_jitter() +
#     geom_rug()

# %% [markdown]
# ### Dotplot (with jitter)

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_jitter()

# %% [markdown]
# **👉 Try It**
#
# Here is an example of a dotplot (with jitter). It's a bit easier to read, but it's hard to make sense of since the y axis is meaningless. Read some documentation and learn how to:
#
# - Add a **title** and **subtitle** that helps explain what story this data is telling. <br/>
#     (_Remember, use a narrative title and a descriptive subtitle. The title should tell a story, the subtitle should say what the data is exactly._)

# %%
# %%R
#
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Try It" question

# %% [markdown]
# **👉 Bonus**
# - Remove the y axis labels (and text)
# - Improve the text on the X axis label
# - Change the default theme, explain why you picked the one you picked.

# %%
# %%R
#
# # copy/paste the code from the cell above
# # and then make your modifications to answer
# # "Bonus" question

# %% [markdown]
# ### Density Plot

# %%
# %%R -w 1000 -h 200
# ggplot(df) +
#     aes(x=pct_below_poverty) +
#     geom_density()

# %% [markdown]
# > Density Plot is the continuous and smoothed version of the Histogram estimated from the data. It is estimated through Kernel Density Estimation.
#
# Source: https://www.geeksforgeeks.org/histograms-and-density-plots-in-python/

# %% [markdown]
# 👉 Try It
#
# This one is entirely theoretical. Google around and then take your best shot at answering the following questions:
#
# 1) When might you want to use a density plot versus a histogram?
#
# > when the values have very slight differeances between them, making finding meaningful bin sizes difficult.
#
# 2) What is Kernel Density Estimation and how does it work?
#
# > I think Kernel Density estimation is a way to smooth out datapoints into a density curve that works like a clay molding tool. You drag the tool over eacg point to smooth out the gradiant between points.

# %% [markdown]
# ### Box and Whisker Plot
# http://www.sthda.com/english/wiki/ggplot2-box-plot-quick-start-guide-r-software-and-data-visualization

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_boxplot(alpha=.2,outlier.size=10)

# %% [markdown]
# Box and whisker plots aren't super easy to read. We don't always use them in reader-facing visualizations, but you'll find them a lot in scientific papers. Box and whisker plots help draw attention to outliers in relation to the median and interquartile range of the data.

# %% [markdown]
# ##### Interpreting a Boxplot
# ![](images/boxplot-image.png)
# > **Not all boxplots are created equal!**
# >
# >"Not all boxplots are created equal. There are many different ways in which quantiles can be defined. For example, some will compute a quantile as (i−0.5)/n
#  where i
#  is the nth element of the batch of data and n
#  is the total number of elements in that batch. This is the method implemented by Bill Cleveland and we will refer to this method as Cleveland’s quantile method. This also happens to be the method implemented by the base’s boxplot function which explains the different boxplot output compared to ggplot_boxplot in our working example:
#
#
# source: https://mgimond.github.io/ES218/Week05a.html

# %% [markdown]
# **👉 Try It**
#
# Our box and whisker plot is showing three outliers with very high poverty rates. See if you can:
# - figure out how to annotate those so that we know which zipcodes they are
# - add a title and subtitle explaining to the reader what they're looking at
#
# **👉 Bonus**
# - Can you also annotate which borough the outliers are in?

# %%
# %%R -w 1000 -h 200
#
#
# # Claude's Take
#
# Q1 <- quantile(df$pct_below_poverty, 0.25)
# Q3 <- quantile(df$pct_below_poverty, 0.75)
# IQR <- Q3 - Q1
# outlier_threshold <- Q3 + 1.5 * IQR
#
# outliers <- df %>% filter(pct_below_poverty > outlier_threshold)
#
#
# # modify this code
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_boxplot(alpha=.2,outlier.size=10) +
#      geom_label(data=outliers,
#                aes(label=zip),
#                nudge_y=0.15,
#                size=3)

# %% [markdown]
# ### Violin Plot

# %%
# %%R -w 1000 -h 200
#
# ggplot(df) +
#     aes(x=pct_below_poverty, y=1) +
#     geom_violin()

# %% [markdown]
# **👉 Try It**
#
# Violin plots are great in that they help the reader to see nuances in the density a bit better than the box and whisker plot. However, they can be hard to interpret. Showing the dots in/on the violin plot can help.
#
# See if you can find a way to plot the dots in or on the violin plot to help the reader better understand what they're looking it.

# %% [markdown]
# ### Beeswarm
# (this requires installing a package)
#
# https://github.com/eclarke/ggbeeswarm

# %% [markdown]
# **👉 Try It (Bonus!)**
#
# Install the package above and show the density as a beeswarm rather than just a jitter.
